# %% [markdown]
# # Релиз 2.0

# %% [markdown]
# ## Импортируем библиотеки

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_columns = None

# %% [markdown]
# ## Начинаем работу с колонками

# %%
df = pd.read_csv('/home/Rena/bootcamp_ds/week_3/project1/_data.csv')

# %%
df
# Out:
#        Unnamed: 0  ID  объявления Количество комнат       Тип  \
# 0               0       271271157                 4  Квартира
# 1               1       271634126                 4  Квартира
# 2               2       271173086   4, Оба варианта  Квартира
# 3               3       272197456   4, Оба варианта  Квартира
# 4               4       273614615                 2  Квартира
# ...           ...             ...               ...       ...
# 23363       23363       215565511               NaN  Квартира
# 23364       23364       274654844                 1  Квартира
# 23365       23365       268679909   2, Оба варианта  Квартира
# 23366       23366       274807525                 2  Квартира
# 23367       23367       274672243   2, Оба варианта  Квартира
#
#                               Метро  \
# 0      м. Смоленская (9 мин пешком)
# 1      м. Смоленская (8 мин пешком)
# 2      м. Смоленская (7 мин пешком)
# 3      м. Смоленская (3 мин пешком)
# 4       м. Арбатская (7 мин пешком)
# ...                             ...
# 23363    м. Говорово (8 мин пешком)
# 23364    м. Солнцево (7 мин пешком)
# 23365    м. Солнцево (6 мин пешком)
# 23366   м. Солнцево (11 мин пешком)
# 23367   м. Говорово (10 мин пешком)
#
#                                                    Адрес      Площадь, м2  \
# 0                          Москва, улица Новый Арбат, 27       200.0/20.0
# 1                          Москва, улица Новый Арбат, 27  198.0/95.0/18.0
# 2                          Москва, улица Новый Арбат, 27  200.0/116.0/4.0
# 3                       Москва, переулок Плотников, 21С1  170.0/95.0/17.0
# 4                          Москва, улица Новый Арбат, 15    58.0/38.0/5.0
# ...                                                  ...              ...
# 23363  Москва, Боровское шоссе, 2к7, ш. Боровское (3 ...    35.0/16.4/8.0
# 23364  Москва, Производственная улица, 8к1, ш. Боровс...   38.7/16.5/11.0
# 23365                       Москва, Боровский проезд, 11             43.1
# 23366  Москва, улица Богданова, 6к1, ш. Боровское (3 ...        52.5/10.0
# 23367  Москва, улица Богданова, 2к1, ш. Боровское (3 ...   90.0/48.2/15.5
#
#                              Дом   Парковка  \
# 0               5/16, Монолитный  подземная
# 1      5/16, Монолитно-кирпичный  подземная
# 2                           5/16  подземная
# 3                            5/6  подземная
# 4               12/26, Панельный        NaN
# ...                          ...        ...
# 23363                      10/14        NaN
# 23364           5/18, Монолитный        NaN
# 23365             5/5, Кирпичный        NaN
# 23366           8/23, Монолитный   наземная
# 23367            6/23, Панельный        NaN
#
#                                                     Цена  \
# 0      500000.0 руб./ За месяц, Залог - 500000 руб., ...
# 1      500000.0 руб./ За месяц, Залог - 500000 руб., ...
# 2      500000.0 руб./ За месяц, Залог - 500000 руб., ...
# 3      400000.0 руб./ За месяц, Залог - 400000 руб., ...
# 4      225000.0 руб./ За месяц, Залог - 225000 руб., ...
# ...                                                  ...
# 23363  42000.0 руб./ За месяц, Залог - 42000 руб., Ко...
# 23364  45000.0 руб./ За месяц, Залог - 45000 руб., Ко...
# 23365  50000.0 руб./ За месяц, Залог - 50000 руб., Ко...
# 23366  55000.0 руб./ За месяц, Залог - 50000 руб., Ко...
# 23367  57000.0 руб./ За месяц, Залог - 60000 руб., Ко...
#
#                          Телефоны  \
# 0                    +79166369231
# 1                    +79850608590
# 2      +79672086536, +79099269384
# 3      +79660342340, +79099269384
# 4                    +79852432860
# ...                           ...
# 23363                +79154383401
# 23364                +79151173402
# 23365                +79653825192
# 23366                +79660611965
# 23367                +79623641533
#
#                                                 Описание         Ремонт  \
# 0      Без комиссии для нанимателя! Бонус коллегам 12...   Дизайнерский
# 1      Лот 93107. Елена Анисимова.\n\nБонус агенту 50...   Дизайнерский
# 2      ID 36380:  Шикарная 4-х км. квартира в ЖК "Нов...     Евроремонт
# 3      ID 31618:  Эксклюзивное предложение. Современн...     Евроремонт
# 4      Лот 111542. Татьяна Лучкина.\n\nБонус агенту 5...     Евроремонт
# ...                                                  ...            ...
# 23363  Сдаётся светлая теплая квартира (студия) с бал...     Евроремонт
# 23364  Сдам однокомнатную квартиру на длительный срок...     Евроремонт
# 23365  Рассматриваются квартиранты только славяне и т...   Дизайнерский
# 23366  Двухкомнатная уютная квартира с видом во внутр...     Евроремонт
# 23367  Сдается просторная двухкомнатная квартира ВПЕР...  Косметический
#
#       Площадь комнат, м2      Балкон             Окна  \
# 0                    NaN         NaN              NaN
# 1            25 25 20 25         NaN  На улицу и двор
# 2                    NaN         NaN  На улицу и двор
# 3            14-42-20-19         NaN  На улицу и двор
# 4                  20 18         NaN  На улицу и двор
# ...                  ...         ...              ...
# 23363                NaN  Балкон (1)              NaN
# 23364                NaN  Лоджия (1)          Во двор
# 23365                NaN  Балкон (1)  На улицу и двор
# 23366                NaN  Лоджия (1)          Во двор
# 23367     26,2+15,5-22,0  Лоджия (1)          Во двор
#
#                                Санузел           Можно с детьми/животными  \
# 0                                  NaN  Можно с детьми, Можно с животными
# 1      Совмещенный (2), Раздельный (1)                     Можно с детьми
# 2                      Совмещенный (3)                     Можно с детьми
# 3                      Совмещенный (3)                  Можно с животными
# 4                      Совмещенный (2)                                NaN
# ...                                ...                                ...
# 23363                  Совмещенный (1)                                NaN
# 23364                  Совмещенный (1)                                NaN
# 23365                  Совмещенный (1)                     Можно с детьми
# 23366  Совмещенный (1), Раздельный (1)                                NaN
# 23367                   Раздельный (1)  Можно с детьми, Можно с животными
#
#                                            Дополнительно        Название ЖК  \
# 0      Мебель в комнатах, Мебель на кухне, Ванна, Душ...  Новый Арбат, 2010
# 1      Мебель в комнатах, Мебель на кухне, Ванна, Душ...        Новый Арбат
# 2      Мебель в комнатах, Мебель на кухне, Ванна, Душ...        Новый Арбат
# 3      Мебель в комнатах, Мебель на кухне, Ванна, Душ...                NaN
# 4      Мебель в комнатах, Мебель на кухне, Ванна, Душ...           The Book
# ...                                                  ...                ...
# 23363  Мебель в комнатах, Мебель на кухне, Ванна, Сти...      Мещерский лес
# 23364  Мебель в комнатах, Мебель на кухне, Ванна, Сти...               Лучи
# 23365  Мебель на кухне, Душевая кабина, Стиральная ма...                NaN
# 23366  Мебель в комнатах, Мебель на кухне, Ванна, Сти...                NaN
# 23367  Мебель в комнатах, Мебель на кухне, Ванна, Сти...                NaN
#
#       Серия дома  Высота потолков, м                Лифт Мусоропровод  \
# 0            NaN                3.00  Пасс (4), Груз (1)           Да
# 1            NaN                3.50  Пасс (1), Груз (1)          Нет
# 2            NaN                3.20            Пасс (1)          NaN
# 3            NaN                3.20            Пасс (1)          NaN
# 4            NaN                3.90  Пасс (1), Груз (1)           Да
# ...          ...                 ...                 ...          ...
# 23363        NaN                 NaN  Пасс (1), Груз (1)          NaN
# 23364        NaN                 NaN  Пасс (1), Груз (1)          NaN
# 23365        NaN                 NaN                 NaN          NaN
# 23366        NaN                2.65            Пасс (3)           Да
# 23367        NaN                 NaN            Пасс (3)           Да
#
#                           Ссылка на объявление
# 0      https://www.cian.ru/rent/flat/271271157
# 1      https://www.cian.ru/rent/flat/271634126
# 2      https://www.cian.ru/rent/flat/271173086
# 3      https://www.cian.ru/rent/flat/272197456
# 4      https://www.cian.ru/rent/flat/273614615
# ...                                        ...
# 23363  https://www.cian.ru/rent/flat/215565511
# 23364  https://www.cian.ru/rent/flat/274654844
# 23365  https://www.cian.ru/rent/flat/268679909
# 23366  https://www.cian.ru/rent/flat/274807525
# 23367  https://www.cian.ru/rent/flat/274672243
#
# [23368 rows x 25 columns]

# %%
#Выкидываем ненужные колонки
df = df.drop(columns=['Серия дома', 'Ссылка на объявление', 'Телефоны', 'Описание', 'Unnamed: 0', 'Название ЖК', 'Можно с детьми/животными', 'Тип'])

# %%
#Исправили цену (теперь только цена/мес)
def price(s):
    return int(s.split('.')[0])

df['Цена'] = df['Цена'].apply(price)

# %%
#Удалим дубликаты по ID
df.drop_duplicates(subset=['ID  объявления'], keep='first', inplace=True)

# %%
#Удаляем все, кроме Москвы
df = df[df['Адрес'].str.contains('Москва')].reset_index()

# %% [markdown]
# ## Работаем с пропусками

# %%
#Сколько NaN и где? (проверяю по мере заполнения)
df.isna().sum()
# Out:
# index                     0
# ID  объявления            0
# Количество комнат       535
# Метро                   346
# Адрес                     0
# Площадь, м2               0
# Дом                       0
# Парковка              11174
# Цена                      0
# Ремонт                 2463
# Площадь комнат, м2     7228
# Балкон                 6630
# Окна                   5150
# Санузел                2041
# Дополнительно           272
# Высота потолков, м     9202
# Лифт                   4192
# Мусоропровод           8007
# dtype: int64

# %%
#Помучаемся с адресами... Убираем шоссе оттуда, где оно есть
df['Адрес'] = [x.split('ш. ')[0] for x in df['Адрес']]

# %%
#Создаем список всех возможных улиц для редактирования
lst = df['Адрес'].tolist()

# %%
#Манипуляции с адресами..
lst1 = [str(index) + ', ' + features for index, features in enumerate(lst)]

# %%
lst2 = [x.split(',') for x in lst1]
lst3 = [' '.join(' '.join(x).strip().split()[2:-1]) for x in lst2]

#Обновляем колонку в df
df['Адрес'] = lst3

# %%
#Парковка (заменяем NaN)
df['Парковка'] = df['Парковка'].fillna('бесплатная во дворе')

# %%
#Количество комнат (если длина строки больше 1 - значит там не только значение, вытаскиваем его по индексу)
def room_count(s):
    if len(s) > 1:
        return int(s.split(',')[0])
    else:
        return int(s)
df['Количество комнат'] = df['Количество комнат'].fillna('0')
df['Количество комнат'] = df['Количество комнат'].apply(room_count)

# %%
#Метро (заполняем NaN)
df['Метро'] = df['Метро'].fillna('м. Отсутствует рядом (0 мин пешком)')
df['Метро'] = [x.split(' (')[0] for x in df['Метро']]
df['Метро'] = [x.split('. ')[1] for x in df['Метро']]

# %%
df['Ремонт'] = df['Ремонт'].fillna('Без ремонта')

# %%
#Площадь - заполним пробелы
df['Площадь общая, м2'] = [float(x.split('/')[0]) for x in df['Площадь, м2']]

# %%
#Выкинем теперь площадь комнат
df = df.drop(columns=['Площадь комнат, м2', 'Площадь, м2'])

# %%
#Балконы - заполним NaN, разделим по двум столбцам
df['Балкон'] = df['Балкон'].fillna('Балкон (0)')
df['Лоджия'] = [x.split(' ')[-1] if x.split(' ')[-2] == 'Лоджия' else 0 for x in df['Балкон']]
df['Балкон'] = [x.split(' ')[1] if x.split(' ')[0] == 'Балкон' else 0 for x in df['Балкон']]

# %%
#Убрать скобки у балконов
df['Балкон'] = [int(x[1]) if type(x) == str else 0 for x in df['Балкон']]
df['Лоджия'] = [int(x[1]) if type(x) == str else 0 for x in df['Лоджия']]

# %%
#Окна - заполним NaN 
df['Окна'] = df['Окна'].fillna('На улицу или двор')

# %%
#Санузлы - делаем как с балконами
df['Санузел'] = df['Санузел'].fillna('Совмещенный (1)')
df['Санузел разд.'] = [x.split(' ')[-1] if x.split(' ')[-2] == 'Раздельный' else 0 for x in df['Санузел']]
df['Санузел совм.'] = [x.split(' ')[1] if x.split(' ')[0] == 'Совмещенный' else 0 for x in df['Санузел']]

# %%
#Вторая часть про санузлы - вытащили значения, сделали из них int принудительно :)
df['Санузел разд.'] = [int(x[1]) if type(x) == str else 0 for x in df['Санузел разд.']]
df['Санузел совм.'] = [int(x[1]) if type(x) == str else 0 for x in df['Санузел совм.']]
df = df.drop(columns=['Санузел'])

# %%
#Разберемся с колонкой "Дополнительно". Логика такая -> не прописано - значит квартира пустая
df['Дополнительно'] = df['Дополнительно'].fillna('Отсутствует')

# %%
#Сделаем в колонке два вывода - "Присутствуют удобства" если там все, кроме "Отсутствует", и "Отсутствуют удобства" в ином случае
df['Дополнительно'] = ['Отсутствуют удобства' if x == 'Отсутствует' else 'Присутствуют удобства' for x in df['Дополнительно']]

# %%
#Потолки... настало ваше время... Пропуски заполним средним значением, округлим после точки до двух символов
#Предварительно переведем см в м (надеемся, что трехзначные числа - это см)
df['Высота потолков, м'] = [x / 100 if x > 30 else x for x in df['Высота потолков, м']]
df['Высота потолков, м'] = [x / 10 if x > 20 else x for x in df['Высота потолков, м']]
df['Высота потолков, м'] = df['Высота потолков, м'].fillna(round(df['Высота потолков, м'].mean(), 2))

# %%
#Из колонки Дом получить колонку Дом и Этаж
df['Тип дома'] = [x.split(', ')[-1] if len(x.split(', ')[-1]) > 6 else 'Неизвестно' for x in df['Дом']]
df['Количество этажей'] = [int(x.split('/')[1].split(',')[0]) for x in df['Дом']]
df['Этаж квартиры'] = [int(x.split('/')[0]) for x in df['Дом']]
df = df.drop(['Дом'], axis=1)

# %%
#Лифты. Заполним NaN - пусть будет Пасс (0), Груз (0), если меньше 5 этажей
df['Лифт'] = [x if x == x else ['Пасс (1), Груз (1)' if df['Количество этажей'].iloc[i]>5 else 'Пасс (0), Груз (0)'][0]for i, x in enumerate(df['Лифт'])]

# %%
#Разделим лифты на две колонки - груз и пасс, удалим старую колонку
df['Лифт груз.'] = [x.split(' ')[-1] if x.split(' ')[-2] == 'Груз' else 0 for x in df['Лифт']]
df['Лифт пасс.'] = [x.split(' ')[1] if x.split(' ')[0] == 'Пасс' else 0 for x in df['Лифт']]

# %%
#Заменим у лифтов значения на type=int + выкинем ненужную колонку
df['Лифт груз.'] = [int(x[1]) if type(x) == str else 0 for x in df['Лифт груз.']]
df['Лифт пасс.'] = [int(x[1]) if type(x) == str else 0 for x in df['Лифт пасс.']]
df = df.drop(columns=['Лифт'])

# %%
#Обработаем мусоропровод от NaN
df['Мусоропровод'] = df['Мусоропровод'].fillna('Нет')

# %%
#Уберем цену в конец графика
last_column = df.pop('Цена')
df.insert(df.shape[1], 'Цена', last_column)

# %% [markdown]
# ## Итоговый DF после удаления всех NaN:

# %%
df
# Out:
#        index  ID  объявления  Количество комнат       Метро  \
# 0          0       271271157                  4  Смоленская
# 1          1       271634126                  4  Смоленская
# 2          2       271173086                  4  Смоленская
# 3          3       272197456                  4  Смоленская
# 4          4       273614615                  2   Арбатская
# ...      ...             ...                ...         ...
# 19732  23363       215565511                  0    Говорово
# 19733  23364       274654844                  1    Солнцево
# 19734  23365       268679909                  2    Солнцево
# 19735  23366       274807525                  2    Солнцево
# 19736  23367       274672243                  2    Говорово
#
#                         Адрес             Парковка         Ремонт  Балкон  \
# 0           улица Новый Арбат            подземная   Дизайнерский       0
# 1           улица Новый Арбат            подземная   Дизайнерский       0
# 2           улица Новый Арбат            подземная     Евроремонт       0
# 3          переулок Плотников            подземная     Евроремонт       0
# 4           улица Новый Арбат  бесплатная во дворе     Евроремонт       0
# ...                       ...                  ...            ...     ...
# 19732         Боровское шоссе  бесплатная во дворе     Евроремонт       1
# 19733  Производственная улица  бесплатная во дворе     Евроремонт       0
# 19734        Боровский проезд  бесплатная во дворе   Дизайнерский       1
# 19735         улица Богданова             наземная     Евроремонт       0
# 19736         улица Богданова  бесплатная во дворе  Косметический       0
#
#                     Окна          Дополнительно  Высота потолков, м  \
# 0      На улицу или двор  Присутствуют удобства                3.00
# 1        На улицу и двор  Присутствуют удобства                3.50
# 2        На улицу и двор  Присутствуют удобства                3.20
# 3        На улицу и двор  Присутствуют удобства                3.20
# 4        На улицу и двор  Присутствуют удобства                3.90
# ...                  ...                    ...                 ...
# 19732  На улицу или двор  Присутствуют удобства                2.76
# 19733            Во двор  Присутствуют удобства                2.76
# 19734    На улицу и двор  Присутствуют удобства                2.76
# 19735            Во двор  Присутствуют удобства                2.65
# 19736            Во двор  Присутствуют удобства                2.76
#
#       Мусоропровод  Площадь общая, м2  Лоджия  Санузел разд.  Санузел совм.  \
# 0               Да              200.0       0              0              1
# 1              Нет              198.0       0              1              2
# 2              Нет              200.0       0              0              3
# 3              Нет              170.0       0              0              3
# 4               Да               58.0       0              0              2
# ...            ...                ...     ...            ...            ...
# 19732          Нет               35.0       0              0              1
# 19733          Нет               38.7       1              0              1
# 19734          Нет               43.1       0              0              1
# 19735           Да               52.5       1              1              1
# 19736           Да               90.0       1              1              0
#
#                   Тип дома  Количество этажей  Этаж квартиры  Лифт груз.  \
# 0               Монолитный                 16              5           1
# 1      Монолитно-кирпичный                 16              5           1
# 2               Неизвестно                 16              5           0
# 3               Неизвестно                  6              5           0
# 4                Панельный                 26             12           1
# ...                    ...                ...            ...         ...
# 19732           Неизвестно                 14             10           1
# 19733           Монолитный                 18              5           1
# 19734            Кирпичный                  5              5           0
# 19735           Монолитный                 23              8           0
# 19736            Панельный                 23              6           0
#
#        Лифт пасс.    Цена
# 0               4  500000
# 1               1  500000
# 2               1  500000
# 3               1  400000
# 4               1  225000
# ...           ...     ...
# 19732           1   42000
# 19733           1   45000
# 19734           0   50000
# 19735           3   55000
# 19736           3   57000
#
# [19737 rows x 22 columns]

# %% [markdown]
# # Поменяем названия согласно ТЗ.

# %%
#Создадим словарь для переименования колонок
new_column_names = {
    'ID  объявления':'ID',
    'Количество комнат':'room_number',
    'Метро':'subway',
    'Адрес':'address',
    'Парковка':'parking',
    'Ремонт':'home_renovation',
    'Балкон':'balcony',
    'Окна':'windows',
    'Дополнительно':'additional_amenities',
    'Высота потолков, м':'ceiling_height',
    'Мусоропровод':'garbage_chute',
    'Площадь общая, м2':'total_area',
    'Площадь жилая, м2':'living_area',
    'Площадь кухня, м2':'kitchen_area',
    'Лоджия':'loggia',
    'Санузел разд.':'separate_bathroom',
    'Санузел совм.':'shared_bathroom',
    'Тип дома':'building_type',
    'Количество этажей':'floors_number',
    'Этаж квартиры':'apartment_floor',
    'Лифт груз.':'freight_elevator',
    'Лифт пасс.':'passenger_elevator',
    'Цена':'price'}

# %%
df = df.rename(columns=new_column_names)
df = df.drop(columns=['index'])

# %%
#Выгрузим готовый DataFrame в .csv формат
df.to_csv('data.csv', index=False)
